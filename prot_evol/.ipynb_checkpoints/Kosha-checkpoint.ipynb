# %%
print("PP")
# Out:
# PP

# %%
import random
import Bio
import numpy as np
import matplotlib.pyplot as plt
import scipy
from scipy.spatial import distance

# %%
amino_acids = ["G", "R", "N", "D", "C", "E", "Q", "A", "H", "I", "L", "K", "M", "F", "P", "S", "T", "W", "Y", "V"]

# %%
amino_acid_codes = np.random.uniform((1/20), (400-19)/400, 400)
amino_acid_codes
# Out:
# array([0.72883338, 0.78857613, 0.86699216, 0.17686392, 0.21967398,
#        0.60433197, 0.59564121, 0.79740999, 0.36687317, 0.48795795,
#        0.11627012, 0.90323883, 0.76900603, 0.44490093, 0.58969524,
#        0.85937943, 0.51733956, 0.78068796, 0.4515532 , 0.182766  ,
#        0.05610957, 0.83238686, 0.8904403 , 0.43832797, 0.06265725,
#        0.50685462, 0.21840907, 0.26974415, 0.34557057, 0.75704869,
#        0.12244305, 0.48255136, 0.11438991, 0.93109645, 0.63225465,
#        0.79880722, 0.74605168, 0.23683485, 0.75547356, 0.43842584,
#        0.45786571, 0.36807914, 0.54358115, 0.8987417 , 0.49066771,
#        0.63098709, 0.61403834, 0.50452329, 0.06136324, 0.05137595,
#        0.61863666, 0.38138172, 0.73505491, 0.20861506, 0.07658683,
#        0.81290502, 0.08042545, 0.60756907, 0.62596954, 0.94731598,
#        0.40295761, 0.87505237, 0.82051225, 0.65648514, 0.15201751,
#        0.81366812, 0.81294391, 0.5460533 , 0.44682624, 0.60848512,
#        0.65510982, 0.71240815, 0.23453325, 0.45636201, 0.57026484,
#        0.7463553 , 0.87956687, 0.73952236, 0.08366364, 0.08247299,
#        0.53745824, 0.30808841, 0.9148041 , 0.65769401, 0.7195094 ,
#        0.28283326, 0.80733891, 0.44746408, 0.24902527, 0.07193875,
#        0.63641292, 0.21626986, 0.78678615, 0.27992628, 0.59468624,
#        0.8482759 , 0.35992041, 0.49358667, 0.39342066, 0.62591751,
#        0.19309573, 0.80466867, 0.5037762 , 0.21943569, 0.77052034,
#        0.38957129, 0.73629052, 0.93532505, 0.14835424, 0.58407494,
#        0.09807014, 0.08931985, 0.53206516, 0.42947185, 0.63217054,
#        0.60554581, 0.59575345, 0.50390556, 0.21091457, 0.34511555,
#        0.90654178, 0.31916727, 0.60753687, 0.47979125, 0.21024172,
#        0.29833327, 0.07759109, 0.27789922, 0.89587765, 0.30934623,
#        0.62698159, 0.34957582, 0.22017165, 0.83979075, 0.40159417,
#        0.15968913, 0.0541161 , 0.73058257, 0.5137863 , 0.62374881,
#        0.79112647, 0.4873462 , 0.90782837, 0.15961085, 0.4922073 ,
#        0.52687904, 0.73610082, 0.66345517, 0.32372393, 0.07625966,
#        0.65542335, 0.19075285, 0.79403933, 0.7985696 , 0.82794147,
#        0.06981672, 0.29969577, 0.22319588, 0.76179133, 0.80451913,
#        0.54191688, 0.94936013, 0.68726566, 0.12817948, 0.83416596,
#        0.60031704, 0.72483927, 0.6962759 , 0.66456589, 0.73603635,
#        0.06383141, 0.26260253, 0.84957299, 0.49629402, 0.27862845,
#        0.61559025, 0.77628777, 0.94123356, 0.87107607, 0.59260895,
#        0.06459534, 0.68512809, 0.28843489, 0.91769346, 0.89320626,
#        0.17158283, 0.53649199, 0.21842059, 0.36116784, 0.28832803,
#        0.93242719, 0.76058913, 0.18654609, 0.17194649, 0.13042433,
#        0.31273471, 0.05014776, 0.15084865, 0.06982806, 0.0772622 ,
#        0.24236637, 0.34333819, 0.78633098, 0.18003143, 0.8231206 ,
#        0.86547125, 0.71119436, 0.19091352, 0.39584318, 0.10869881,
#        0.35677165, 0.61824155, 0.40101052, 0.78831911, 0.42281802,
#        0.71682541, 0.53777317, 0.12975308, 0.34609347, 0.1714946 ,
#        0.19243746, 0.84741377, 0.83729312, 0.78353175, 0.1083245 ,
#        0.50221416, 0.66228319, 0.42569118, 0.27045081, 0.22739541,
#        0.15632055, 0.05865779, 0.92184243, 0.5868944 , 0.38746171,
#        0.35093623, 0.79377558, 0.41692823, 0.57345251, 0.61322977,
#        0.79433508, 0.44932673, 0.19879564, 0.72941415, 0.19836428,
#        0.80723879, 0.3453948 , 0.69008742, 0.89713995, 0.05572807,
#        0.63795783, 0.3126454 , 0.5242434 , 0.31599354, 0.50717478,
#        0.0686632 , 0.08732343, 0.39667332, 0.45719185, 0.45875198,
#        0.78888003, 0.74728766, 0.71378614, 0.05004526, 0.33933906,
#        0.14966652, 0.30546768, 0.28717904, 0.27664057, 0.9268913 ,
#        0.40963768, 0.69087205, 0.81925528, 0.73069826, 0.63338319,
#        0.72679185, 0.22728282, 0.91899677, 0.63216743, 0.16539278,
#        0.65835965, 0.59394008, 0.52588862, 0.46155661, 0.36008112,
#        0.09932268, 0.09260659, 0.35271493, 0.44659411, 0.8014221 ,
#        0.4267855 , 0.46718431, 0.10284387, 0.14107652, 0.76172374,
#        0.74260763, 0.83718466, 0.78382725, 0.66045676, 0.79964755,
#        0.54514668, 0.19410648, 0.20667292, 0.2712331 , 0.83392988,
#        0.12026693, 0.87436818, 0.13134262, 0.91030506, 0.36455546,
#        0.24015359, 0.7348348 , 0.43377133, 0.38196208, 0.41189751,
#        0.78962761, 0.18008245, 0.15796527, 0.2321561 , 0.72275774,
#        0.36852096, 0.60148612, 0.54617996, 0.21827781, 0.28762032,
#        0.82340804, 0.64241145, 0.08046622, 0.06013054, 0.42278009,
#        0.25591647, 0.16152389, 0.2629401 , 0.92857818, 0.48950643,
#        0.1676889 , 0.65342349, 0.0533604 , 0.4130585 , 0.58745768,
#        0.77301205, 0.76884457, 0.61998745, 0.39964823, 0.70503864,
#        0.5550339 , 0.75546168, 0.76976272, 0.84338343, 0.9406394 ,
#        0.47113162, 0.08759599, 0.864644  , 0.75878879, 0.34089733,
#        0.47010198, 0.41854889, 0.77543321, 0.19799651, 0.32735028,
#        0.05743344, 0.06863704, 0.94586994, 0.41553266, 0.56060858,
#        0.21544124, 0.68397265, 0.29051495, 0.3419019 , 0.22307798,
#        0.55580215, 0.88718676, 0.36397523, 0.45423735, 0.20729104,
#        0.35513089, 0.53697016, 0.45422069, 0.26082489, 0.69023858,
#        0.27034512, 0.24145463, 0.08564332, 0.23541758, 0.46893806,
#        0.18146233, 0.52890036, 0.70511994, 0.43545372, 0.83076204,
#        0.3148692 , 0.40253217, 0.49846877, 0.61683061, 0.07074671,
#        0.18166004, 0.19648964, 0.42360837, 0.63486665, 0.65563857])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 [(1-c)/19]
#
# NameError: name 'c' is not defined

# %%
def GenerateSEQ(NumSEQ):
    amino_acids = ["G", "R", "N", "D", "C", "E", "Q", "A", "H", "I", "L", "K", "M", "F", "P", "S", "T", "W", "Y", "V"]
    listSEQ = []
    fav_aa_fr = np.random.uniform((1/20), (400-19)/400, NumSEQ)
    for c in fav_aa_fr:
        rand_seq=random.choices(amino_acids, weights=([c]+[(1-c)/19]*19), k = 400)
        joinedrand = rand_seq = ''.join(rand_seq)
        listSEQ.append(joinedrand)
    return(listSEQ)

# %%
LISTSEQ = GenerateSEQ(400)

# %%
hamming_distances = []

for i in range(len(LISTSEQ)):
    for j in range(i + 1, len(LISTSEQ)):
        seq1 = list(LISTSEQ[i])
        seq2 = list(LISTSEQ[j])
        hamming_distance = distance.hamming(seq1, seq2)
        hamming_distances.append((hamming_distance))

hamming_distances
# Out:
# [np.float64(0.765),
#  np.float64(0.84),
#  np.float64(0.8975),
#  np.float64(0.51),
#  np.float64(0.955),
#  np.float64(0.7025),
#  np.float64(0.8275),
#  np.float64(0.51),
#  np.float64(0.7725),
#  np.float64(0.7925),
#  np.float64(0.685),
#  np.float64(0.4475),
#  np.float64(0.67),
#  np.float64(0.7275),
#  np.float64(0.32),
#  np.float64(0.57),
#  np.float64(0.7025),
#  np.float64(0.6675),
#  np.float64(0.7725),
#  np.float64(0.58),
#  np.float64(0.325),
#  np.float64(0.8),
#  np.float64(0.63),
#  np.float64(0.895),
#  np.float64(0.5925),
#  np.float64(0.5725),
#  np.float64(0.865),
#  np.float64(0.45),
#  np.float64(0.7725),
#  np.float64(0.385),
#  np.float64(0.4375),
#  np.float64(0.69),
#  np.float64(0.5125),
#  np.float64(0.7975),
#  np.float64(0.58),
#  np.float64(0.785),
#  np.float64(0.7225),
#  np.float64(0.445),
#  np.float64(0.5675),
#  np.float64(0.465),
#  np.float64(0.3375),
#  np.float64(0.4675),
#  np.float64(0.8025),
#  np.float64(0.425),
#  np.float64(0.4675),
#  np.float64(0.45),
#  np.float64(0.935),
#  np.float64(0.275),
#  np.float64(0.515),
#  np.float64(0.88),
#  np.float64(0.69),
#  np.float64(0.9),
#  np.float64(0.5775),
#  np.float64(0.79),
#  np.float64(0.71),
#  np.float64(0.53),
#  np.float64(0.6375),
#  np.float64(0.5775),
#  np.float64(0.84),
#  np.float64(0.6175),
#  np.float64(0.75),
#  np.float64(0.59),
#  np.float64(0.2925),
#  np.float64(0.815),
#  np.float64(0.9125),
#  np.float64(0.6675),
#  np.float64(0.8225),
#  np.float64(0.76),
#  np.float64(0.705),
#  np.float64(0.635),
#  np.float64(0.565),
#  np.float64(0.345),
#  np.float64(0.715),
#  np.float64(0.4625),
#  np.float64(0.6375),
#  np.float64(0.475),
#  np.float64(0.8475),
#  np.float64(0.37),
#  np.float64(0.57),
#  np.float64(0.7775),
#  np.float64(0.71),
#  np.float64(0.5375),
#  np.float64(0.74),
#  np.float64(0.4625),
#  np.float64(0.625),
#  np.float64(0.49),
#  np.float64(0.52),
#  np.float64(0.8975),
#  np.float64(0.615),
#  np.float64(0.665),
#  np.float64(0.5925),
#  np.float64(0.7475),
#  np.float64(0.9225),
#  np.float64(0.4),
#  np.float64(0.6925),
#  np.float64(0.71),
#  np.float64(0.5175),
#  np.float64(0.77),
#  np.float64(0.8125),
#  np.float64(0.4925),
#  np.float64(0.875),
#  np.float64(0.415),
#  np.float64(0.4925),
#  np.float64(0.3575),
#  np.float64(0.6725),
#  np.float64(0.665),
#  np.float64(0.3575),
#  np.float64(0.3425),
#  np.float64(0.35),
#  np.float64(0.335),
#  np.float64(0.885),
#  np.float64(0.2775),
#  np.float64(0.575),
#  np.float64(0.4),
#  np.float64(0.2925),
#  np.float64(0.82),
#  np.float64(0.685),
#  np.float64(0.5575),
#  np.float64(0.9525),
#  np.float64(0.895),
#  np.float64(0.645),
#  np.float64(0.6025),
#  np.float64(0.42),
#  np.float64(0.2975),
#  np.float64(0.385),
#  np.float64(0.5225),
#  np.float64(0.6925),
#  np.float64(0.6325),
#  np.float64(0.575),
#  np.float64(0.7175),
#  np.float64(0.7025),
#  np.float64(0.3525),
#  np.float64(0.765),
#  np.float64(0.6675),
#  np.float64(0.7375),
#  np.float64(0.7075),
#  np.float64(0.3875),
#  np.float64(0.5675),
#  np.float64(0.445),
#  np.float64(0.3125),
#  np.float64(0.8375),
#  np.float64(0.66),
#  np.float64(0.3375),
#  np.float64(0.8125),
#  np.float64(0.7325),
#  np.float64(0.73),
#  np.float64(0.7575),
#  np.float64(0.7175),
#  np.float64(0.665),
#  np.float64(0.92),
#  np.float64(0.725),
#  np.float64(0.9025),
#  np.float64(0.91),
#  np.float64(0.3475),
#  np.float64(0.305),
#  np.float64(0.2875),
#  np.float64(0.5775),
#  np.float64(0.875),
#  np.float64(0.8175),
#  np.float64(0.71),
#  np.float64(0.53),
#  np.float64(0.6525),
#  np.float64(0.755),
#  np.float64(0.4175),
#  np.float64(0.4425),
#  np.float64(0.8),
#  np.float64(0.795),
#  np.float64(0.5825),
#  np.float64(0.57),
#  np.float64(0.7475),
#  np.float64(0.81),
#  np.float64(0.91),
#  np.float64(0.56),
#  np.float64(0.53),
#  np.float64(0.305),
#  np.float64(0.82),
#  np.float64(0.35),
#  np.float64(0.4575),
#  np.float64(0.7675),
#  np.float64(0.4275),
#  np.float64(0.655),
#  np.float64(0.7925),
#  np.float64(0.61),
#  np.float64(0.46),
#  np.float64(0.655),
#  np.float64(0.61),
#  np.float64(0.4575),
#  np.float64(0.7825),
#  np.float64(0.6025),
#  np.float64(0.575),
#  np.float64(0.67),
#  np.float64(0.4675),
#  np.float64(0.625),
#  np.float64(0.33),
#  np.float64(0.2825),
#  np.float64(0.585),
#  np.float64(0.7975),
#  np.float64(0.63),
#  np.float64(0.76),
#  np.float64(0.5625),
#  np.float64(0.5025),
#  np.float64(0.835),
#  np.float64(0.4825),
#  np.float64(0.4775),
#  np.float64(0.8925),
#  np.float64(0.6825),
#  np.float64(0.42),
#  np.float64(0.6475),
#  np.float64(0.41),
#  np.float64(0.5425),
#  np.float64(0.68),
#  np.float64(0.4175),
#  np.float64(0.365),
#  np.float64(0.53),
#  np.float64(0.9075),
#  np.float64(0.4725),
#  np.float64(0.9275),
#  np.float64(0.34),
#  np.float64(0.5675),
#  np.float64(0.335),
#  np.float64(0.5325),
#  np.float64(0.4775),
#  np.float64(0.505),
#  np.float64(0.765),
#  np.float64(0.5875),
#  np.float64(0.5225),
#  np.float64(0.5025),
#  np.float64(0.4825),
#  np.float64(0.8475),
#  np.float64(0.605),
#  np.float64(0.8125),
#  np.float64(0.42),
#  np.float64(0.395),
#  np.float64(0.45),
#  np.float64(0.8975),
#  np.float64(0.5175),
#  np.float64(0.2925),
#  np.float64(0.415),
#  np.float64(0.485),
#  np.float64(0.62),
#  np.float64(0.9075),
#  np.float64(0.9475),
#  np.float64(0.795),
#  np.float64(0.8625),
#  np.float64(0.865),
#  np.float64(0.4875),
#  np.float64(0.6775),
#  np.float64(0.6975),
#  np.float64(0.4825),
#  np.float64(0.4125),
#  np.float64(0.6925),
#  np.float64(0.2875),
#  np.float64(0.37),
#  np.float64(0.4875),
#  np.float64(0.28),
#  np.float64(0.85),
#  np.float64(0.935),
#  np.float64(0.715),
#  np.float64(0.715),
#  np.float64(0.295),
#  np.float64(0.9175),
#  np.float64(0.5325),
#  np.float64(0.335),
#  np.float64(0.385),
#  np.float64(0.6625),
#  np.float64(0.47),
#  np.float64(0.6425),
#  np.float64(0.79),
#  np.float64(0.6475),
#  np.float64(0.6475),
#  np.float64(0.2875),
#  np.float64(0.3175),
#  np.float64(0.36),
#  np.float64(0.3725),
#  np.float64(0.725),
#  np.float64(0.875),
#  np.float64(0.425),
#  np.float64(0.2975),
#  np.float64(0.675),
#  np.float64(0.61),
#  np.float64(0.6875),
#  np.float64(0.7325),
#  np.float64(0.295),
#  np.float64(0.8325),
#  np.float64(0.51),
#  np.float64(0.6575),
#  np.float64(0.905),
#  np.float64(0.8675),
#  np.float64(0.32),
#  np.float64(0.7975),
#  np.float64(0.445),
#  np.float64(0.69),
#  np.float64(0.8375),
#  np.float64(0.82),
#  np.float64(0.315),
#  np.float64(0.7425),
#  np.float64(0.7775),
#  np.float64(0.7),
#  np.float64(0.4275),
#  np.float64(0.4825),
#  np.float64(0.2925),
#  np.float64(0.495),
#  np.float64(0.6075),
#  np.float64(0.55),
#  np.float64(0.6575),
#  np.float64(0.8),
#  np.float64(0.4275),
#  np.float64(0.68),
#  np.float64(0.4575),
#  np.float64(0.9175),
#  np.float64(0.9575),
#  np.float64(0.92),
#  np.float64(0.8825),
#  np.float64(0.8875),
#  np.float64(0.53),
#  np.float64(0.8075),
#  np.float64(0.7925),
#  np.float64(0.5125),
#  np.float64(0.645),
#  np.float64(0.46),
#  np.float64(0.655),
#  np.float64(0.37),
#  np.float64(0.295),
#  np.float64(0.575),
#  np.float64(0.93),
#  np.float64(0.3675),
#  np.float64(0.3025),
#  np.float64(0.4),
#  np.float64(0.6625),
#  np.float64(0.95),
#  np.float64(0.835),
#  np.float64(0.545),
#  np.float64(0.8525),
#  np.float64(0.5125),
#  np.float64(0.5275),
#  np.float64(0.6475),
#  np.float64(0.735),
#  np.float64(0.47),
#  np.float64(0.77),
#  np.float64(0.53),
#  np.float64(0.925),
#  np.float64(0.515),
#  np.float64(0.7625),
#  np.float64(0.9025),
#  np.float64(0.6025),
#  np.float64(0.85),
#  np.float64(0.6225),
#  np.float64(0.31),
#  np.float64(0.76),
#  np.float64(0.745),
#  np.float64(0.8475),
#  np.float64(0.6175),
#  np.float64(0.465),
#  np.float64(0.7525),
#  np.float64(0.3625),
#  np.float64(0.43),
#  np.float64(0.935),
#  np.float64(0.305),
#  np.float64(0.66),
#  np.float64(0.6475),
#  np.float64(0.3025),
#  np.float64(0.3925),
#  np.float64(0.6825),
#  np.float64(0.935),
#  np.float64(0.3675),
#  np.float64(0.6775),
#  np.float64(0.4825),
#  np.float64(0.7475),
#  np.float64(0.265),
#  np.float64(0.6875),
#  np.float64(0.9325),
#  np.float64(0.5525),
#  np.float64(0.36),
#  np.float64(0.56),
#  np.float64(0.815),
#  np.float64(0.4725),
#  np.float64(0.7525),
#  np.float64(0.72),
#  np.float64(0.91),
#  np.float64(0.905),
#  np.float64(0.8225),
#  np.float64(0.465),
#  np.float64(0.7125),
#  np.float64(0.4),
#  np.float64(0.42),
#  np.float64(0.87),
#  np.float64(0.7775),
#  np.float64(0.6525),
#  np.float64(0.3875),
#  np.float64(0.8925),
#  np.float64(0.55),
#  np.float64(0.8625),
#  np.float64(0.505),
#  np.float64(0.76),
#  np.float64(0.62),
#  np.float64(0.5425),
#  np.float64(0.3075),
#  np.float64(0.4825),
#  np.float64(0.5425),
#  np.float64(0.9),
#  np.float64(0.925),
#  np.float64(0.79),
#  np.float64(0.9575),
#  np.float64(0.8725),
#  np.float64(0.9),
#  np.float64(0.805),
#  np.float64(0.88),
#  np.float64(0.895),
#  np.float64(0.865),
#  np.float64(0.77),
#  np.float64(0.85),
#  np.float64(0.8725),
#  np.float64(0.7425),
#  np.float64(0.8325),
#  np.float64(0.8575),
#  np.float64(0.8425),
#  np.float64(0.8875),
#  np.float64(0.8325),
#  np.float64(0.73),
#  np.float64(0.9025),
#  np.float64(0.8325),
#  np.float64(0.9325),
#  np.float64(0.8225),
#  np.float64(0.8375),
#  np.float64(0.9275),
#  np.float64(0.8),
#  np.float64(0.88),
#  np.float64(0.76),
#  np.float64(0.7775),
#  np.float64(0.855),
#  np.float64(0.8),
#  np.float64(0.9025),
#  np.float64(0.83),
#  np.float64(0.855),
#  np.float64(0.8775),
#  np.float64(0.7875),
#  np.float64(0.8075),
#  np.float64(0.805),
#  np.float64(0.74),
#  np.float64(0.79),
#  np.float64(0.905),
#  np.float64(0.775),
#  np.float64(0.7975),
#  np.float64(0.7825),
#  np.float64(0.965),
#  np.float64(0.71),
#  np.float64(0.8025),
#  np.float64(0.9375),
#  np.float64(0.8475),
#  np.float64(0.9125),
#  np.float64(0.8375),
#  np.float64(0.885),
#  np.float64(0.89),
#  np.float64(0.7975),
#  np.float64(0.8225),
#  np.float64(0.82),
#  np.float64(0.905),
#  np.float64(0.8325),
#  np.float64(0.895),
#  np.float64(0.8175),
#  np.float64(0.745),
#  np.float64(0.8925),
#  np.float64(0.93),
#  np.float64(0.8475),
#  np.float64(0.91),
#  np.float64(0.86),
#  np.float64(0.8675),
#  np.float64(0.835),
#  np.float64(0.8),
#  np.float64(0.75),
#  np.float64(0.8725),
#  np.float64(0.7875),
#  np.float64(0.845),
#  np.float64(0.815),
#  np.float64(0.915),
#  np.float64(0.7625),
#  np.float64(0.82),
#  np.float64(0.88),
#  np.float64(0.855),
#  np.float64(0.8225),
#  np.float64(0.875),
#  np.float64(0.775),
#  np.float64(0.8275),
#  np.float64(0.77),
#  np.float64(0.8),
#  np.float64(0.93),
#  np.float64(0.8075),
#  np.float64(0.8475),
#  np.float64(0.8325),
#  np.float64(0.88),
#  np.float64(0.95),
#  np.float64(0.7425),
#  np.float64(0.855),
#  np.float64(0.865),
#  np.float64(0.805),
#  np.float64(0.8925),
#  np.float64(0.9475),
#  np.float64(0.805),
#  np.float64(0.93),
#  np.float64(0.765),
#  np.float64(0.8075),
#  np.float64(0.745),
#  np.float64(0.8575),
#  np.float64(0.8475),
#  np.float64(0.77),
#  np.float64(0.7525),
#  np.float64(0.75),
#  np.float64(0.745),
#  np.float64(0.925),
#  np.float64(0.7375),
#  np.float64(0.825),
#  np.float64(0.7675),
#  np.float64(0.7275),
#  np.float64(0.89),
#  np.float64(0.8575),
#  np.float64(0.83),
#  np.float64(0.9475),
#  np.float64(0.9225),
#  np.float64(0.835),
#  np.float64(0.815),
#  np.float64(0.7625),
#  np.float64(0.7325),
#  np.float64(0.77),
#  np.float64(0.815),
#  np.float64(0.865),
#  np.float64(0.8425),
#  np.float64(0.815),
#  np.float64(0.85),
#  np.float64(0.8625),
#  np.float64(0.745),
#  np.float64(0.8775),
#  np.float64(0.88),
#  np.float64(0.86),
#  np.float64(0.8675),
#  np.float64(0.745),
#  np.float64(0.795),
#  np.float64(0.77),
#  np.float64(0.735),
#  np.float64(0.91),
#  np.float64(0.86),
#  np.float64(0.7375),
#  np.float64(0.905),
#  np.float64(0.8725),
#  np.float64(0.8675),
#  np.float64(0.9025),
#  np.float64(0.8675),
#  np.float64(0.85),
#  np.float64(0.91),
#  np.float64(0.8875),
#  np.float64(0.935),
#  np.float64(0.9425),
#  np.float64(0.7475),
#  np.float64(0.72),
#  np.float64(0.7175),
#  np.float64(0.82),
#  np.float64(0.905),
#  np.float64(0.9175),
#  np.float64(0.855),
#  np.float64(0.8),
#  np.float64(0.86),
#  np.float64(0.8925),
#  np.float64(0.7925),
#  np.float64(0.7775),
#  np.float64(0.92),
#  np.float64(0.9225),
#  np.float64(0.815),
#  np.float64(0.8425),
#  np.float64(0.915),
#  np.float64(0.9075),
#  np.float64(0.92),
#  np.float64(0.8175),
#  np.float64(0.81),
#  np.float64(0.7275),
#  np.float64(0.9025),
#  np.float64(0.755),
#  np.float64(0.78),
#  np.float64(0.8925),
#  np.float64(0.77),
#  np.float64(0.82),
#  np.float64(0.88),
#  np.float64(0.83),
#  np.float64(0.7775),
#  np.float64(0.8375),
#  np.float64(0.8425),
#  np.float64(0.77),
#  np.float64(0.8925),
#  np.float64(0.8375),
#  np.float64(0.85),
#  np.float64(0.8375),
#  np.float64(0.8),
#  np.float64(0.8475),
#  np.float64(0.75),
#  np.float64(0.72),
#  np.float64(0.8075),
#  np.float64(0.915),
#  np.float64(0.835),
#  np.float64(0.9),
#  np.float64(0.835),
#  np.float64(0.8025),
#  np.float64(0.92),
#  np.float64(0.7725),
#  np.float64(0.8025),
#  np.float64(0.94),
#  np.float64(0.8725),
#  np.float64(0.7625),
#  np.float64(0.845),
#  np.float64(0.77),
#  np.float64(0.81),
#  np.float64(0.8575),
#  np.float64(0.77),
#  np.float64(0.755),
#  np.float64(0.815),
#  np.float64(0.9475),
#  np.float64(0.7675),
#  np.float64(0.9475),
#  np.float64(0.7475),
#  np.float64(0.82),
#  np.float64(0.74),
#  np.float64(0.8175),
#  np.float64(0.7975),
#  np.float64(0.8175),
#  np.float64(0.9075),
#  np.float64(0.8375),
#  np.float64(0.81),
#  np.float64(0.815),
#  np.float64(0.7725),
#  np.float64(0.895),
#  np.float64(0.815),
#  np.float64(0.9075),
#  np.float64(0.7675),
#  np.float64(0.7675),
#  np.float64(0.7725),
#  np.float64(0.9325),
#  np.float64(0.8225),
#  np.float64(0.7175),
#  np.float64(0.765),
#  np.float64(0.7975),
#  np.float64(0.8375),
#  np.float64(0.9275),
#  np.float64(0.94),
#  np.float64(0.9025),
#  np.float64(0.9),
#  np.float64(0.9225),
#  np.float64(0.7775),
#  np.float64(0.835),
#  np.float64(0.8575),
#  np.float64(0.795),
#  np.float64(0.7775),
#  np.float64(0.87),
#  np.float64(0.7175),
#  np.float64(0.765),
#  np.float64(0.8075),
#  np.float64(0.72),
#  np.float64(0.9225),
#  np.float64(0.9375),
#  np.float64(0.885),
#  np.float64(0.87),
#  np.float64(0.73),
#  np.float64(0.92),
#  np.float64(0.8075),
#  np.float64(0.7225),
#  np.float64(0.7675),
#  np.float64(0.8225),
#  np.float64(0.7825),
#  np.float64(0.835),
#  np.float64(0.905),
#  np.float64(0.875),
#  np.float64(0.85),
#  np.float64(0.7275),
#  np.float64(0.735),
#  np.float64(0.745),
#  np.float64(0.765),
#  np.float64(0.8575),
#  np.float64(0.915),
#  np.float64(0.76),
#  np.float64(0.7325),
#  np.float64(0.8425),
#  np.float64(0.845),
#  np.float64(0.855),
#  np.float64(0.845),
#  np.float64(0.7325),
#  np.float64(0.92),
#  np.float64(0.8125),
#  np.float64(0.84),
#  np.float64(0.9225),
#  np.float64(0.945),
#  np.float64(0.725),
#  np.float64(0.8875),
#  np.float64(0.77),
#  np.float64(0.8575),
#  np.float64(0.9175),
#  np.float64(0.8975),
#  np.float64(0.7425),
#  np.float64(0.88),
#  np.float64(0.9025),
#  np.float64(0.87),
#  np.float64(0.795),
#  np.float64(0.7925),
#  np.float64(0.725),
#  np.float64(0.8225),
#  np.float64(0.8375),
#  np.float64(0.8),
#  np.float64(0.845),
#  np.float64(0.9125),
#  np.float64(0.7925),
#  np.float64(0.86),
#  np.float64(0.775),
#  np.float64(0.945),
#  np.float64(0.95),
#  np.float64(0.94),
#  np.float64(0.915),
#  np.float64(0.94),
#  np.float64(0.8025),
#  np.float64(0.89),
#  np.float64(0.8825),
#  np.float64(0.8075),
#  np.float64(0.83),
#  np.float64(0.765),
#  np.float64(0.825),
#  np.float64(0.7575),
#  np.float64(0.725),
#  np.float64(0.81),
#  np.float64(0.945),
#  np.float64(0.745),
#  np.float64(0.725),
#  np.float64(0.76),
#  np.float64(0.8125),
#  np.float64(0.9525),
#  np.float64(0.905),
#  np.float64(0.82),
#  np.float64(0.9175),
#  np.float64(0.805),
#  np.float64(0.8125),
#  np.float64(0.815),
#  np.float64(0.885),
#  np.float64(0.795),
#  np.float64(0.89),
#  np.float64(0.8075),
#  np.float64(0.9375),
#  np.float64(0.7975),
#  np.float64(0.8825),
#  np.float64(0.9425),
#  np.float64(0.835),
#  np.float64(0.92),
#  np.float64(0.8425),
#  np.float64(0.7225),
#  np.float64(0.8875),
#  np.float64(0.8525),
#  np.float64(0.8975),
#  np.float64(0.85),
#  np.float64(0.775),
#  np.float64(0.8825),
#  np.float64(0.755),
#  np.float64(0.7675),
#  np.float64(0.9625),
#  np.float64(0.7375),
#  np.float64(0.87),
#  np.float64(0.8375),
#  np.float64(0.735),
#  np.float64(0.7575),
#  np.float64(0.8675),
#  np.float64(0.955),
#  np.float64(0.775),
#  np.float64(0.8625),
#  np.float64(0.7875),
#  np.float64(0.8975),
#  np.float64(0.715),
#  np.float64(0.8675),
#  np.float64(0.9225),
#  np.float64(0.8175),
#  np.float64(0.7475),
#  np.float64(0.8125),
#  np.float64(0.92),
#  np.float64(0.7925),
#  np.float64(0.89),
#  np.float64(0.87),
#  np.float64(0.935),
#  np.float64(0.95),
#  np.float64(0.895),
#  np.float64(0.7825),
#  np.float64(0.8625),
#  np.float64(0.765),
#  np.float64(0.775),
#  np.float64(0.9275),
#  np.float64(0.905),
#  np.float64(0.8625),
#  np.float64(0.77),
#  np.float64(0.925),
#  np.float64(0.8125),
#  np.float64(0.92),
#  np.float64(0.8),
#  np.float64(0.8575),
#  np.float64(0.8175),
#  np.float64(0.8025),
#  np.float64(0.7475),
#  np.float64(0.785),
#  np.float64(0.805),
#  np.float64(0.9575),
#  np.float64(0.85),
#  np.float64(0.9325),
#  np.float64(0.8925),
#  np.float64(0.9425),
#  np.float64(0.85),
#  np.float64(0.895),
#  np.float64(0.9225),
#  np.float64(0.8975),
#  np.float64(0.8275),
#  np.float64(0.8975),
#  np.float64(0.8875),
#  np.float64(0.805),
#  np.float64(0.865),
#  np.float64(0.8825),
#  np.float64(0.8875),
#  np.float64(0.885),
#  np.float64(0.8725),
#  np.float64(0.81),
#  np.float64(0.925),
#  np.float64(0.8825),
#  np.float64(0.9325),
#  np.float64(0.89),
#  np.float64(0.8575),
#  np.float64(0.945),
#  np.float64(0.83),
#  np.float64(0.89),
#  np.float64(0.8425),
#  np.float64(0.815),
#  np.float64(0.8925),
#  np.float64(0.84),
#  np.float64(0.905),
#  np.float64(0.875),
#  np.float64(0.89),
#  np.float64(0.89),
#  np.float64(0.845),
#  np.float64(0.8625),
#  np.float64(0.8575),
#  np.float64(0.8275),
#  np.float64(0.8575),
#  np.float64(0.935),
#  np.float64(0.8375),
#  np.float64(0.8325),
#  np.float64(0.855),
#  np.float64(0.945),
#  np.float64(0.7925),
#  np.float64(0.8575),
#  np.float64(0.9375),
#  np.float64(0.8975),
#  np.float64(0.935),
#  np.float64(0.8775),
#  np.float64(0.9125),
#  np.float64(0.92),
#  np.float64(0.87),
#  np.float64(0.86),
#  np.float64(0.8625),
#  np.float64(0.9325),
#  np.float64(0.8675),
#  np.float64(0.9075),
#  np.float64(0.8575),
#  np.float64(0.8075),
#  np.float64(0.945),
#  np.float64(0.955),
#  np.float64(0.915),
#  np.float64(0.9175),
#  np.float64(0.9325),
#  np.float64(0.88),
#  np.float64(0.9025),
#  np.float64(0.8725),
#  np.float64(0.825),
#  np.float64(0.9225),
#  np.float64(0.865),
#  np.float64(0.875),
#  np.float64(0.84),
#  np.float64(0.92),
#  np.float64(0.8325),
#  np.float64(0.87),
#  np.float64(0.9025),
#  np.float64(0.895),
#  np.float64(0.8725),
#  np.float64(0.9175),
#  np.float64(0.8525),
#  np.float64(0.8675),
#  np.float64(0.845),
#  np.float64(0.865),
#  np.float64(0.935),
#  np.float64(0.8925),
#  np.float64(0.8825),
#  np.float64(0.89),
#  np.float64(0.9375),
#  np.float64(0.94),
#  np.float64(0.8475),
#  np.float64(0.905),
#  np.float64(0.8975),
#  np.float64(0.8575),
#  np.float64(0.9025),
#  np.float64(0.9275),
#  np.float64(0.85),
#  np.float64(0.9375),
#  np.float64(0.8175),
#  np.float64(0.855),
#  np.float64(0.835),
#  np.float64(0.8775),
#  np.float64(0.9025),
#  np.float64(0.82),
#  np.float64(0.835),
#  np.float64(0.825),
#  np.float64(0.825),
#  np.float64(0.945),
#  np.float64(0.8125),
#  np.float64(0.875),
#  np.float64(0.8275),
#  np.float64(0.805),
#  np.float64(0.9175),
#  np.float64(0.9025),
#  np.float64(0.8775),
#  np.float64(0.9375),
#  np.float64(0.935),
#  np.float64(0.89),
#  np.float64(0.875),
#  np.float64(0.835),
#  np.float64(0.805),
#  np.float64(0.8275),
#  np.float64(0.885),
#  np.float64(0.9075),
#  np.float64(0.8675),
#  np.float64(0.88),
#  np.float64(0.8675),
#  np.float64(0.8925),
#  np.float64(0.8225),
#  np.float64(0.9025),
#  np.float64(0.89),
#  np.float64(0.9025),
#  np.float64(0.905),
#  np.float64(0.8275),
#  np.float64(0.8675),
#  np.float64(0.8375),
#  np.float64(0.815),
#  np.float64(0.935),
#  np.float64(0.9025),
#  np.float64(0.8175),
#  np.float64(0.93),
#  np.float64(0.8925),
#  np.float64(0.9175),
#  np.float64(0.925),
#  np.float64(0.915),
#  np.float64(0.8825),
#  np.float64(0.9575),
#  np.float64(0.8975),
#  np.float64(0.9575),
#  np.float64(0.94),
#  np.float64(0.8225),
#  np.float64(0.805),
#  np.float64(0.8125),
#  np.float64(0.8675),
#  np.float64(0.915),
#  np.float64(0.915),
#  np.float64(0.9075),
#  np.float64(0.8775),
#  np.float64(0.885),
#  np.float64(0.895),
#  np.float64(0.8425),
#  np.float64(0.8675),
#  np.float64(0.9125),
#  np.float64(0.9075),
#  np.float64(0.885),
#  np.float64(0.875),
#  np.float64(0.895),
#  np.float64(0.9325),
#  np.float64(0.925),
#  np.float64(0.8675),
#  np.float64(0.87),
#  np.float64(0.7925),
#  np.float64(0.94),
#  np.float64(0.8325),
#  np.float64(0.855),
#  np.float64(0.8975),
#  np.float64(0.8275),
#  np.float64(0.87),
#  np.float64(0.92),
#  np.float64(0.865),
#  np.float64(0.845),
#  np.float64(0.885),
#  np.float64(0.9),
#  np.float64(0.84),
#  np.float64(0.92),
#  np.float64(0.8825),
#  np.float64(0.8675),
#  np.float64(0.89),
#  np.float64(0.845),
#  np.float64(0.8625),
#  np.float64(0.8325),
#  np.float64(0.8225),
#  np.float64(0.855),
#  np.float64(0.9325),
#  np.float64(0.8775),
#  np.float64(0.89),
#  np.float64(0.85),
#  np.float64(0.8525),
#  np.float64(0.9225),
#  np.float64(0.86),
#  np.float64(0.8575),
#  np.float64(0.9475),
#  ...]

# %%
len(hamming_distances)
# Out:
# 79800

# %%
array_hamming_distances = np.array(hamming_distances)
array_hamming_distances
# Out:
# array([0.765 , 0.84  , 0.8975, ..., 0.42  , 0.48  , 0.5875])

# %%
plt.hist(array_hamming_distances)

plt.xlabel("hamming distance")
plt.ylabel("quantity of sequences")
# Out:
# Text(0, 0.5, 'quantity of sequences')

# %%
#importing modules
import argparse
import pandas as pd
import re
import os
import numpy as np
import itertools
from scipy import stats
import ast
#from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import math

# %%
def t_student_one_sided(sample_size, p=0.05):
    # One-sided inverse Students t-distribution
    # p - probability, df - degrees of freedom
    tinv = lambda p, df: abs(stats.t.ppf(p, df))
    return(tinv(p, sample_size-2)) # Returns: The critical value from the one-sided t-distribution.

def get_curves_LD_all_kcoefs_ranges(k, log=False, norm=False,  numbins=40, nparray=False, in_folder='', from_file=False, flat=False):
    """Function to plot the number of pairs at a given distance against the distance"""
    
    #read pairwise distance matrix as an 1d array
    # if flat==True:
    #     k, size= matrix
    # else:
    #     k,size=squareform(matrix, nparray=nparray, in_folder=in_folder, from_file=from_file)
    size = len(k)
    #creates a histogram of the distances
    if log==True:
        # using logspace so that the points appear to be equally spaced in the log scale
        binn=np.histogram(k, bins=list(np.append(np.zeros(1), np.logspace(-2.99573227,0,numbins,base=math.e))))
    else:
        binn=np.histogram(k, bins=list(np.linspace(0,1, numbins+1)))
    #get x axis (range of pairwise distances)
    dista=np.log(binn[1][1:])
    #get y axis (cumulative pairs counts)
    cumulative=np.cumsum(binn[0])
    
    #check if there are any empty bins at small distances
    #if there are any, these bins will be excluded (because np.log(0)=-inf which is a problem during dimension calculation)
    if 0 in cumulative:
        last0_ind=np.where(cumulative==0)[0][-1]+1
        cumulative=cumulative[last0_ind:]
        dista=dista[last0_ind:]
    #normalize y scale or not: DOES NOT alter dimension value in the end, only usefull for visualization purposes
    if norm==True:
        # applying the Normalization: log(E)/N^2
        return(dista, np.log(cumulative/size**2))
    else:
        return(dista, np.log(cumulative))
    
def max_k(matrix, log=False, win_size_perc=0.1, numbins=40, t_stud=None, mode='max', norm=False, plot=True, in_folder='', out_folder='',out_plots='',nparray=False,from_file=True,save_picture=False, flat=False, label=''):
    
    """
    Function to calculate dimension from the matrix of pairwise distances.
    Supports three modes of calculation: 
    - MODE="max": dimension is the highest slope of the linear regression slopes done on all windows of size WIN_SIZE_PERC*NUMBINS
    - MODE="min_max": same as "max" mode + it gives a min_k value - the slope of the curve from 0% sequence distance to (but not including) the 
      first point included in region used to calculate max_k
    - MODE="min_max_50": function outputs the "max" and "min" dimension values and "0-50%" dimension 
      (the slope of the linear regression done on the first WIN_SIZE_PERC*NUMBINS (0-WIN_SIZE_PERC% divergence))
    """
    #get the file name prefix 
    # if flat==False:
    #     fn=re.findall('(.+)\.', matrix)[0]
    # else:
    #     fn='simulated_matrix'
    
    #get x and y for regression, where
    #x - pairwise distance in log scale (0-100% divergence)
    #y - log of number of pairs per bin at a a given pairwise distance
    (x, y)=get_curves_LD_all_kcoefs_ranges(matrix, log=log, norm =norm, numbins=numbins, nparray=nparray, in_folder=in_folder, from_file = from_file, flat=flat)

    slopes = []
    x_range = []
    rvals= []
    sterrs = []
    bs = []
    
    win_size=int(win_size_perc*numbins)
    length=len(x)
        #to find maximun slope check all intervals of the curve of length WIN_SIZE
    for i in range(len(x)-win_size+1):
        win_x=x[i:i+win_size]
        win_y=y[i:i+win_size]
        slope, b, r_value, p_value, std_err =  stats.linregress(win_x, win_y)
        #record only positive slopes
        if slope <= 0:
            continue
        slopes.append(slope)
        rvals.append(r_value)
        x_range.append(win_x)
        bs.append(b)
        sterrs.append(std_err)
        
    if len(slopes) == 0:
        raise ValueError(
            """
            No positive slopes or no windows
            with all values above threshold found!
            """
            )

    max_k = max(slopes)
    ind=slopes.index(max_k)
    max_x = x_range[ind]
    max_r = rvals[ind]
    max_b = bs[ind]
    
        
    #adjustment in case the actual length of the x axis is different from numbins (empty bins removed in get_curves_LD_all_kcoefs_ranges function)
    difflen=numbins-length    

    #get the range of the distances used to get the highest slope
    if log==True:
        x_coor_nolog=list(np.append(np.zeros(1), np.logspace(-2.99573227,0,numbins,base=math.e)))[difflen:]
        log_str='log'
    else:
        x_coor_nolog=list(np.linspace(0,1, numbins+1))[difflen:]
        log_str='non_log'

    range_start=x_coor_nolog[ind]
    range_end=x_coor_nolog[ind+win_size]

        
    #calculate confidence interval for the slope
    #one sided T Student test is performed because our curve is cumulative, therefore slope will be > 0
    if t_stud!=None and difflen==0:
        #use precalculated t_student value
        max_ci=t_stud*sterrs[ind]
    else:
        t_stud=t_student_one_sided(win_size)
        max_ci=t_stud*sterrs[ind]
    
    
    #saving plot    
    if plot ==True and flat==False:
        plt.scatter(x, y, label= label)
        #plot max slope
        plt.plot(max_x, max_k*max_x + max_b, label="{:.2f}-{:.2f}, y={:.2f}x+{:.2f}\nR^2={:.3f}, 95% CI={:.3f}".format(range_start, range_end, max_k, max_b,max_r**2, max_ci), c='r')
        plt.legend(loc='lower right', prop={'size': 9}) # move the legend 
        plt.ylabel('log(N)')
        plt.xlabel('log(Pairwise distance)')
        if save_picture==True:        
            plt.savefig(out_plots+'%s_%s_%s_%s.png' % (fn, log_str, str(win_size_perc), str(numbins)))
    return(max_k, max_ci)   

max_k(array_hamming_distances)
# Out:
# (np.float64(7.966458767114177), np.float64(1.035234504955112))

# %%
plt.scatter(get_curves_LD_all_kcoefs_ranges(distance)[0], get_curves_LD_all_kcoefs_ranges(distance)[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 plt.scatter(get_curves_LD_all_kcoefs_ranges(distance)[0], get_curves_LD_all_kcoefs_ranges(distance)[1])
#
# Cell In[17], line 15, in get_curves_LD_all_kcoefs_ranges(k, log, norm, numbins, nparray, in_folder, from_file, flat)
#       8 """Function to plot the number of pairs at a given distance against the distance"""
#      10 #read pairwise distance matrix as an 1d array
#      11 # if flat==True:
#      12 #     k, size= matrix
#      13 # else:
#      14 #     k,size=squareform(matrix, nparray=nparray, in_folder=in_folder, from_file=from_file)
# ---> 15 size = len(k)
#      16 #creates a histogram of the distances
#      17 if log==True:
#      18     # using logspace so that the points appear to be equally spaced in the log scale
#
# TypeError: object of type 'module' has no len()
